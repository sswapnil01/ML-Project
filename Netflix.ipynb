# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\user\\Downloads\\Data Science\\Projects\\Netflix'

# %%
df= pd.read_csv('Netflix Dataset.csv')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ## 1. Duplicate records

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates().head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# ## 2. Null values

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
plt.figure(figsize=(12,8),dpi=100)
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. House of cards

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ## To check: isin or str.contains

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df['Title'].isin(['House of Cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %% [markdown]
# ## or

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ## 4. Highest no. of TV shows with Bar graph

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ## first convert to date_time

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'])

# %%
df['Date_N']
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Date_N, Length: 7787, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
x_axis = df['Date_N'].dt.year

# %%
x_axis
# Out:
# 0       2020.0
# 1       2016.0
# 2       2018.0
# 3       2017.0
# 4       2020.0
#          ...
# 7784    2020.0
# 7785    2019.0
# 7786    2020.0
# 7787    2020.0
# 7788    2020.0
# Name: Date_N, Length: 7787, dtype: float64

# %%
y_axis = df['Date_N'].dt.year.value_counts()

# %%
y_axis
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
plt.figure(figsize =(12,6),dpi=200)
sns.barplot(data=df, x= x_axis, y=y_axis)
# Out:
# <AxesSubplot:xlabel='Date_N', ylabel='Date_N'>

# %%
plt.figure(figsize =(6,5),dpi=100)
sns.countplot(data=df, x= x_axis)
# Out:
# <AxesSubplot:xlabel='Date_N', ylabel='count'>

# %% [markdown]
# ## or using  Matplotlib

# %%
df['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %% [markdown]
# ## No. of TV Show & Movie

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# ## or

# %%
df['Category'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.groupby('Category').Category.count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
sns.countplot(data = df, x='Category')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## show movies released in a particular year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df['Year'] = df['Date_N'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2021)]
# Out:
#      Show_Id Category                        Title             Director  \
# 57       s58    Movie                   100% Halal        Jastis Arimba
# 72       s73    Movie                     17 Again          Burr Steers
# 104     s105    Movie           30 Minutes or Less      Ruben Fleischer
# 205     s206    Movie              A Monster Calls          J.A. Bayona
# 366     s367    Movie                    Al acecho  Francisco D'Eufemia
# ...      ...      ...                          ...                  ...
# 7353   s7352    Movie                      Unknown   Jaume Collet-Serra
# 7553   s7552    Movie    What Happened to Mr. Cha?         Kim Dong-kyu
# 7571   s7570    Movie  What Would Sophia Loren Do?        Ross Kauffman
# 7572   s7571    Movie  What's Eating Gilbert Grape      Lasse Hallström
# 7646   s7645    Movie                     Wish You          Sung Do-jun
#
#                                                    Cast  \
# ...

# %% [markdown]
# ## use of filtering

# %%
df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')] ['Cast']
# Out:
# 86                     Luke Kenny, Mohit Raina, Mukul Dev
# 132     Rahman, Havish, Regina Cassandra, Nandita Swet...
# 340     Sharad Kelkar, Aahana Kumra, Mahesh Manjrekar,...
# 364             Kiku Sharda, Vishal Kotian, Delnaaz Irani
# 533                                                   NaN
#                               ...
# 6249                                                  NaN
# 6400                                                  NaN
# 6469                                         Vinay Pathak
# 7294    Aarna Sharma, Aaryansh Malviya, Mikail Gandhi,...
# 7705    Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...
# Name: Cast, Length: 71, dtype: object

# %% [markdown]
# ## Top 10 directors who give maximum no. of TV shows

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter          18
# Marcus Raboy                    16
# Jay Karas                       14
# Cathy Garcia-Molina             13
# Martin Scorsese                 12
#                                 ..
# Harry Elfont, Deborah Kaplan     1
# Karl Mueller                     1
# Fernando Lebrija                 1
# Jacob Joice                      1
# Sunao Katabuchi                  1
# Name: Director, Length: 4050, dtype: int64

# %% [markdown]
# ## category is movie and type is comedies or country is UK

# %%
df[(df['Category'] == 'TV Show') & (df['Country'] == 'India') |(df['Country'] == 'United Kingdom') ]
# Out:
#      Show_Id Category                         Title          Director  \
# 19       s20    Movie                           '89               NaN
# 58       s59  TV Show                   100% Hotter               NaN
# 82       s83    Movie           2036 Origin Unknown     Hasraf Dulull
# 85       s86  TV Show                      21 Again               NaN
# 86       s87  TV Show  21 Sarfarosh: Saragarhi 1897               NaN
# ...      ...      ...                           ...               ...
# 7671   s7670  TV Show        World's Busiest Cities               NaN
# 7688   s7687    Movie        XV: Beyond the Tryline  Pierre Deschamps
# 7705   s7704  TV Show               Yeh Meri Family               NaN
# 7725   s7724    Movie                  You Can Tutu       James Brown
# 7740   s7739  TV Show               Young Wallander               NaN
#
#                                                    Cast         Country  \
# ...

# %% [markdown]
# ## Find movies/TV show in which Tom cruise cast

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year No.  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0   4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#      units
# 0  Seasons
# 1      min

# %%
 df[df.Cast == 'Tom Cruise']      # This will not show as in cast there is not only Tom Cruise

 # df[df['Cast'] == 'Tom Cruise'].value_count()   # FILTERING does not apply whenever there are multiple values in a columns
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year, No., units]
# Index: []

# %% [markdown]
# ## str.contains

# %%
df[df['Cast'].str.contains('Tom Cruise')]   # work with multiple values but this cannot be used with the null values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-ecf9546ec632> in <module>
# ----> 1 df[df['Cast'].str.contains('Tom Cruise')]   # This cannot be used with the null values
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3012
#    3013         # Do we have a (boolean) 1d indexer?
# -> 3014         if com.is_bool_indexer(key):
#    3015             return self._getitem_bool_array(key)
#    3016
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     112                     # Don't raise on e.g. ["A", "B", np.nan], see
#     113                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 114                     raise ValueError(na_msg)
#     115                 return False
#     116             return True
#
# ...

# %% [markdown]
# ## drop null values

# %%
df['Cast'].isnull().sum()
# Out:
# 718

# %%
df1  = df.dropna()

# %%
df1['Cast'].isnull().sum()
# Out:
# 0

# %%
df1[df1['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ## different ratings defined bt Netflix

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ## How many movies got TV-14 rating in canada

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')].head(2)
# Out:
#    Show_Id Category             Title          Director  \
# 30     s31    Movie  #cats_the_mewvie  Michael Margolis
# 34     s35    Movie             #Roxy   Michael Kennedy
#
#                                                  Cast Country  \
# 30                                                NaN  Canada
# 34  Jake Short, Sarah Fisher, Booboo Stewart, Dann...  Canada
#
#         Release_Date Rating Duration                                 Type  \
# 30  February 5, 2020  TV-14   90 min  Documentaries, International Movies
# 34    April 10, 2019  TV-14  105 min            Comedies, Romantic Movies
#
#                                           Description     Date_N    Year
# 30  This pawesome documentary explores how our fel... 2020-02-05  2020.0
# 34  A teenage hacker with a huge nose helps a cool... 2019-04-10  2019.0

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')].shape

# %% [markdown]
# ## find which movie/TV show run for maximum time

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df['Duration'].nunique()
# Out:
# 216

# %%
df['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df.Duration.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# dtype: object

# %%
## so we will first split the Duration coulmn data

# %%
df[['No.', 'units']]  =df['Duration'].str.split(' ', expand = True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year No.  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0   4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#      units
# 0  Seasons
# 1      min

# %%
df['No.'].max()
# Out:
# '99'

# %% [markdown]
# ## which country has max no. of TV shows

# %%
df_TVshow = df[df['Category'] == 'TV Show']

# %%
df_TVshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year No.  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0   4
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0   1
#
#      units
# 0  Seasons
# 5   Season

# %%
df_TVshow['Country'].value_counts()
# Out:
# United States                                     705
# United Kingdom                                    204
# Japan                                             157
# South Korea                                       147
# India                                              71
#                                                  ...
# United Kingdom, Germany, United States, France      1
# South Korea, China                                  1
# Uruguay, Germany                                    1
# Ireland, United Kingdom, United States              1
# Mauritius, South Africa                             1
# Name: Country, Length: 183, dtype: int64

# %%
df_TVshow['Country'].describe()
# Out:
# count              2133
# unique              183
# top       United States
# freq                705
# Name: Country, dtype: object

# %%
df[df_TVshow['Country'] == 'India']       # WHY NOT WORKING?
# Out:
# <ipython-input-84-b7a39b2719a9>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_TVshow['Country'] == 'India']
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-84-b7a39b2719a9> in <module>
# ----> 1 df[df_TVshow['Country'] == 'India']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# ...

# %%
df_TVshow['Country'].value_counts()
# Out:
# United States                                     705
# United Kingdom                                    204
# Japan                                             157
# South Korea                                       147
# India                                              71
#                                                  ...
# United Kingdom, Germany, United States, France      1
# South Korea, China                                  1
# Uruguay, Germany                                    1
# Ireland, United Kingdom, United States              1
# Mauritius, South Africa                             1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# ## Sort dataset by particular column

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year No.  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0   4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#      units
# 0  Seasons
# 1      min

# %%
df.sort_values(by = 'Year', ascending = False).head(5)
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# ...

# %% [markdown]
# ## Find where : category is Movie and Type is Drama or category is TV show & Type is kids TV

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year No.  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0   4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0  93
#
#      units
# 0  Seasons
# 1      min

# %%
df_Movie = df[df['Category'] == 'Movie']

# %%
df_Movie
# Out:
#      Show_Id Category                                    Title  \
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
df_Movie[df_Movie.Type.str.contains('Dramas')]) & (df_TVshow[df_TVshow.Type.str.contains("Kids' TV")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-726ca1c2cbb9> in <module>
# ----> 1 (df_Movie[df_Movie.Type.str.contains('Dramas')]) & (df_TVshow[df_TVshow.Type.str.contains('Kids TV')])
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      57     @unpack_zerodim_and_defer("__and__")
#      58     def __and__(self, other):
# ---> 59         return self._logical_method(other, operator.and_)
#      60
#      61     @unpack_zerodim_and_defer("__rand__")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _arith_method(self, other, op)
# ...

# %%
df[ (df['Category'] == 'Movie') & (df['Category'] == 'Dramas') ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year, No., units]
# Index: []

# %%
df[ (df['Category'] == 'TV Show') & (df['Category'] == "kids' TV") ]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year, No., units]
# Index: []

# %%
df_Movie[df_Movie.Type.str.contains('Dramas')]) & (df_TVshow[df_TVshow.Type.str.contains("kids' TV")]
# Out:
#   File "<ipython-input-113-6e6b47a949b7>", line 1
#     df_Movie[df_Movie.Type.str.contains('Dramas')]) & (df_TVshow[df_TVshow.Type.str.contains("kids' TV")]
#                                                   ^
# SyntaxError: unmatched ')'
